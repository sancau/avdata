# %%
import time
import json
import requests

from random import randint as ri
from bs4 import BeautifulSoup

def parse_avherald(initial_link='http://avherald.com/?list=&opt=1', 
                   max_requests=2, base_url='http://avherald.com', delay=0):
        
    data = {}
    requests_count = 0
    next_link = initial_link
    while requests_count < max_requests:
        """
        Fetching next page..
        """
        try:
            print('Fetching', next_link, '\n', ('-'*40))
            response = requests.get(next_link)
            if response.status_code == 200:
                page = response.content
            if page:
                soup = BeautifulSoup(page, 'html.parser')
                
                # get next page link
                for img in soup.select('a > img'): 
                    if img.get('alt', None) == 'Next':
                        next_link = img.parent['href'].replace('h', '')
                        next_link = base_url + next_link
                        
                # get current page data
                data_container = \
                    soup.findAll('span', {'class': 'headline_avherald'})
                for item in data_container:
                    event_class = \
                        item.parent.parent.parent.select('img')[0]['title']
                    event_description = item.get_text()
                    if event_class in data:
                        data[event_class].append(event_description)
                    else:
                        data[event_class] = [event_description, ]
                data['next_link'] = next_link
        except Exception as e:
            print(e)
        finally:
            requests_count += 1
            if requests_count < max_requests:
                time.sleep(delay)  # delay between requests
    return data
    
# fetching
data = parse_avherald(max_requests=1000, delay=ri(1,5))

json = json.dumps(data)
with open('avherald_data.json', 'w+') as f:
    f.write(json)
    print('Data saved to avherald_data.json')
# Out:
# Fetching http://avherald.com/?list=&opt=1
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20161005000000%2B49f292af
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160926000000%2B49e85e5c
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160918000000%2B49eb3f54
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160908000000%2B49efb31c
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160829000000%2B49d50d48
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160822000000%2B49cfe1b9
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160814000000%2B49cc5991
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160806000000%2B49c516c7
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160729000000%2B49bf1165
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160719000000%2B49b7006f
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160711000000%2B49b0d073
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160702000000%2B49ccef6c
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160623000000%2B49a3a379
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160615000000%2B499cf0b8
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160605000000%2B499552de
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160526000000%2B498dc96c
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160517000000%2B4987ac96
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160508000000%2B498061e2
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160428000000%2B498293e7
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160420000000%2B49743c7a
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160411000000%2B496bb075
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160331000000%2B4964275a
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160320000000%2B495af395
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160311000000%2B4953c0ff
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160303000000%2B494e5980
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160224000000%2B4947ea8b
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160214000000%2B493f2b06
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160205000000%2B493799bd
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160123000000%2B492cf1dd
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160113000000%2B4925aedc
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20160103000000%2B49277bb5
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20151223000000%2B49144221
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20151212000000%2B490d146a
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20151201000000%2B49143870
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20151121000000%2B48fd4fc8
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20151110000000%2B48f3fd8a
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20151030000000%2B48e91a91
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20151019000000%2B49043a4e
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20151010000000%2B48db49ea
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150930000000%2B48d2a3ed
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150919000000%2B48cb6887
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150908000000%2B48c17591
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150830000000%2B48c7bf83
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150819000000%2B48b64aff
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150804000000%2B48a52d85
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150726000000%2B489dee3c
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150716000000%2B4897cd9b
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150707000000%2B48963e64
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150630000000%2B488abde6
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150620000000%2B4883336b
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150610000000%2B487ae676
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150602000000%2B487337e3
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150520000000%2B486d6d79
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150511000000%2B486162ed
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150502000000%2B4878502b
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150422000000%2B48549b76
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150409000000%2B484818ac
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150328000000%2B483dfb32
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150314000000%2B483abb30
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150303000000%2B4829fe81
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150218000000%2B481fe373
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150205000000%2B481734b1
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150125000000%2B480dede5
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150113000000%2B48039258
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20150102000000%2B47fbbc5c
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20141223000000%2B47f49fa1
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20141211000000%2B47ea7473
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20141130000000%2B47e1d0a7
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20141118000000%2B47d770d2
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20141105000000%2B47ce4577
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20141022000000%2B47c33f7a
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20141008000000%2B47b93e1c
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20140926000000%2B47b19c66
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20140916000000%2B47a8f3ab
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110713111656%2B43fa00ab
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110705000000%2B43fad6db%2F0000
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110626000000%2B43ed59ec
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110618000000%2B43e611bf
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110610000000%2B43f98036
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110603000000%2B43d9e227
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110524000000%2B43d16027
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110516000000%2B43cd93df
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110509000000%2B43c4ac83
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110430000000%2B43bceddd
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110422000000%2B43b6ba96
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110414000000%2B43b2c6f4
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110406000000%2B43a92a95
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110328000000%2B43a7e74c
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110319000000%2B4399a5ea
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110310000000%2B4391e170
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110228000000%2B438972b8
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110218000000%2B43809819
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110209000000%2B43793687
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110130000000%2B43714069
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110121000000%2B4369200f
#  ----------------------------------------
# Fetching http://avherald.com/?list=&opt=1&offset=20110112000000%2B4362fd74
#  ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-163-fc1de8c2d7f6> in <module>()
#      49
#      50 # fetching
# ---> 51 data = parse_avherald(max_requests=1000, delay=ri(1,5))
#      52
#      53 json = json.dumps(data)
#
# <ipython-input-163-fc1de8c2d7f6> in parse_avherald(initial_link, max_requests, base_url, delay)
#      45             requests_count += 1
#      46             if requests_count < max_requests:
# ---> 47                 time.sleep(delay)  # delay between requests
#      48     return data
#      49
#
# KeyboardInterrupt:

# %%
MONTHS = [  # need extra space to excelude matching with (for ex.: Novosibirsk)
    'Jan ', 'Feb ', 'Mar ', 'Apr ',  
    'May ', 'Jun ', 'Jul ', 'Aug ', 
    'Sep ', 'Oct ', 'Nov ', 'Dec ' 
]

def parse_info(article, fail_silently=False):
    """Processes article text to get data separated by 
    airline, aircraft, date, place, description
    """
    parts = None
    for m in MONTHS:
        if m in article:
            month_index = article.index(m)
            on_index = month_index - 3
            parts = [ article[:on_index], article[month_index:] ]
    
    if parts is None:
        print(article)
        if not fail_silently:
            raise ValueError('Couldn\'t get parts.')
        return tuple(i for i in '-'*5)
    
    date_and_case = parts[1]
    airline_aircraft_place = parts[0].split(' ')
    date_and_case_words = date_and_case.split(',')
    date = date_and_case_words[0]
    case = ''.join( date_and_case_words[1:] )
    
    place_flag_index = None
    for idx, word in enumerate(airline_aircraft_place):
        if word in ['at', 'over', 'near', 'between']:
            place_flag_index = idx
    if place_flag_index:
        place = ' '.join(airline_aircraft_place[place_flag_index + 1:])
    elif 'enroute' in airline_aircraft_place:
        place = 'enroute'
        place_flag_index = airline_aircraft_place.index('enroute')
    else:
        print('Failed to parse article:', article)
        raise ValueError('Parser error, place_flag_index could not be found.')
        
    airline_aircraft = airline_aircraft_place[:place_flag_index]
    aircraft = airline_aircraft[-1]
    airline = ' '.join(airline_aircraft[:-1])
    
    return airline.strip(), aircraft.strip(), date.strip(), place.strip(), case.strip().capitalize()


def build_dataset(data):
    """Builds structured dataset dictionary
    """
    dataset = {}
    for event_type, events in data.items():
        if event_type not in ['News', 'next_link']:
            for event in events:
                airline, aircraft, date, place, case = parse_info(event, fail_silently=True)
                print(' | '.join([airline, aircraft, date, place, case]))
                
    raise NotImplementedError('TODO')
    return dataset

dataset = build_dataset(data)
# Out:
# KLM | A332 | Oct 14th 2016 | Mediterranean | Turbulence causes injuries
# Sriwijaya | B733 | Oct 11th 2016 | Surabaya | Debris of runway surface punctures fuselage on landing
# Polar | AN26 | Oct 11th 2016 | Belaya Gora | Touched down off runway
# Swiss | RJ1H | Oct 10th 2016 | Geneva | Rejected takeoff due to oil fumes in cockpit
# Sunstate | DH8D | Oct 10th 2016 | Canberra | Turbulence injures 3
# Nordstar | B738 | Oct 9th 2016 | Moscow | Unsafe gear crack found in gear leg
# ANZ | B763 | Oct 9th 2016 | South China Sea | Turbulence causes 4 injuries
# BoraJet | E195 | Oct 19th 2016 | Budapest | Cracked windshield
# British Airways | A319 | Oct 19th 2016 | Manchester | Nose wheel steering fault
# Algerie | AT72 | Oct 19th 2016 | Algiers | Nose wheel departed aircraft on landing
# Aeroflot | A320 | Oct 18th 2016 | Munich | Lightning strike
# Westjet | B763 | Oct 18th 2016 | Sondrestrom | Avionics cooling failure
# Lufthansa | B744 | Oct 18th 2016 | Atlantic | Smoke in cockpit
# Fedex | MD11 | Oct 18th 2016 | Memphis | Dropped part during roll out engine damage
# Binter Canarias | AT72 | Oct 18th 2016 | Tenerife and Gran Canaria | Unsafe main gear
# Calm | AT72 | Oct 17th 2016 | Thompson | Both engines shut down uncommandedly
# Air China | A332 | Oct 16th 2016 | Chengdu | Left is where the thumb is right
# United | B772 | Oct 16th 2016 | Newark | Could not pressurize
# Delta | B739 | Oct 16th 2016 | Salt Lake City | Bird strikes
# Scandinavian | A343 | Oct 15th 2016 | Copenhagen | Engine bleed problem
# Bhutan | A319 | Oct 15th 2016 | Kathmandu | Goat around
# ANA | B737 | Oct 15th 2016 | Nagoya | Whistling windshield
# Peach | A320 | Oct 15th 2016 | Okinawa | Hydraulic failure
# United | B763 | Oct 13th 2016 | Atlantic | Cracked windshield
# TAROM | AT42 | Oct 13th 2016 | Bucharest | Could not fully retract gear
# TAROM | AT72 | Oct 13th 2016 | Bucharest | Rejected takeoff due to gear vibration
# United | A320 | Oct 13th 2016 | Calgary | Autopilot and nose gear problems
# United | B739 | Oct 13th 2016 | Denver | Hit something on departure
# United | B739 | Oct 13th 2016 | Portland | Electrical smell in cabin
# Gojet | CRJ7 | Oct 12th 2016 | Austin | Burst tyre on landing causes flap and engine damage
# American | B788 | Oct 12th 2016 | Pacific | Engine shut down in flight
# American | B773 | Oct 11th 2016 | Pacific | Fuel leak
# Volaris | A320 | Oct 11th 2016 | Guadalajara | Control problems
# PIA | A313 | Oct 11th 2016 | Karachi | Problems with cabin pressure
# Southwest | B738 | Oct 11th 2016 | Portland | Rejected takeoff due to bird strike
# Delta | B752 | Oct 11th 2016 | Shannon | Unsafe gear
# China Eastern | A333 | Oct 11th 2016 | Shanghai | Runway incursion forces departure to rotate early and climb over a333
# Ecojet | RJ85 | Oct 11th 2016 | Riberalta | Runway excursion on backtrack
# Jazz | DH8D | Oct 10th 2016 | Montreal | Temporary loss of control in severe turbulence
# Thai | B788 | Oct 10th 2016 | Denpasar | Engine oil leak
# Etihad | A333 | Oct 9th 2016 | Geneva | Hydraulic failure
# Singapore | B773 | Oct 9th 2016 | Melbourne | Tower observes tailstrike on departure
# Tailwind | B738 | Oct 8th 2016 | Friedrichshafen | Flaps problem
# Germanwings | A319 | Oct 8th 2016 | Belgrade | Fan failure
# Qantas | B744 | Oct 6th 2016 | San Francisco | Bird strike
# Alitalia Cityliner | E175 | Oct 6th 2016 | Milan | Bird strike
# Jet2 | B752 | Oct 6th 2016 | Manchester | Flaps problem
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-162-01af3711f1ff> in <module>()
#      61     return dataset
#      62
# ---> 63 dataset = build_dataset(data)
#
# <ipython-input-162-01af3711f1ff> in build_dataset(data)
#      58                 print(' | '.join([airline, aircraft, date, place, case]))
#      59
# ---> 60     raise NotImplementedError('TODO')
#      61     return dataset
#      62
#
# NotImplementedError: TODO
